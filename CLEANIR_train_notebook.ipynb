# %% [markdown]
# # Prepare a training dataset
# - We use [the test set of VGGFace2](https://github.com/ox-vgg/vgg_face2).
# - You may download the VGGFace2 set or prepare another dataset

# %%
DATA_PATH = '/workspace/data/vgg2_test'

# %% [markdown]
# # Preprocess the datatset
# - Before training, we have to crop faces and/or align it, and extract face embeddings.
# - You might look into "crop_vgg2_data" module for using another dataset.

# %%
PROCESSED_DATA_PATH = '/workspace/data/vgg2_test_processed'

# %%
from cleanir.tools.crop_vgg2_data import *
import os

if not os.path.exists(DATA_PATH):
    print("training data path does not exist")

else:
    os.makedirs(PROCESSED_DATA_PATH, exist_ok=True)
    crop_and_align(DATA_PATH, PROCESSED_DATA_PATH, (64, 64), align=False)
    save_face_encoding(PROCESSED_DATA_PATH)
# Out:
# 100%|██████████| 169396/169396 [2:13:50<00:00, 21.09it/s]
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 100%|██████████| 152507/152507 [1:22:17<00:00, 30.89it/s]

# %% [markdown]
# # Build a CLEANIR network

# %%
from cleanir.cleanir import Cleanir
cleanir = Cleanir(latent_dim=1024)
cleanir.build_network(n_blocks=4, recon_weight=0.3)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /usr/local/lib/python3.5/dist-packages/tqdm/autonotebook/__init__.py:18: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# ## Check summaries of the networks if you want

# %%
cleanir.print_network_summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# res2conv_branch2a (Conv2D)      (None, 16, 16, 64)   36928       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# bn2conv_branch2a (BatchNormaliz (None, 16, 16, 64)   256         res2conv_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 64)   0           bn2conv_branch2a[0][0]
# __________________________________________________________________________________________________
# res2conv_branch2b (Conv2D)      (None, 16, 16, 64)   36928       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# bn2conv_branch2b (BatchNormaliz (None, 16, 16, 64)   256         res2conv_branch2b[0][0]
# __________________________________________________________________________________________________
# res2conv_branch1 (Conv2D)       (None, 16, 16, 64)   36928       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 16, 16, 64)   0           bn2conv_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2conv_branch1 (BatchNormaliza (None, 16, 16, 64)   256         res2conv_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 16, 64)   0           leaky_re_lu_3[0][0]
#                                                                  bn2conv_branch1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 16, 16, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# res2identity_branch2a (Conv2D)  (None, 16, 16, 64)   36928       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# bn2identity_branch2a (BatchNorm (None, 16, 16, 64)   256         res2identity_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 16, 16, 64)   0           bn2identity_branch2a[0][0]
# __________________________________________________________________________________________________
# res2identity_branch2b (Conv2D)  (None, 16, 16, 64)   36928       leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# bn2identity_branch2b (BatchNorm (None, 16, 16, 64)   256         res2identity_branch2b[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 16, 16, 64)   0           bn2identity_branch2b[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 64)   0           leaky_re_lu_6[0][0]
#                                                                  leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 16, 16, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# res3conv_branch2a (Conv2D)      (None, 8, 8, 128)    73856       leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# bn3conv_branch2a (BatchNormaliz (None, 8, 8, 128)    512         res3conv_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 8, 8, 128)    0           bn3conv_branch2a[0][0]
# __________________________________________________________________________________________________
# res3conv_branch2b (Conv2D)      (None, 8, 8, 128)    147584      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# bn3conv_branch2b (BatchNormaliz (None, 8, 8, 128)    512         res3conv_branch2b[0][0]
# __________________________________________________________________________________________________
# res3conv_branch1 (Conv2D)       (None, 8, 8, 128)    73856       leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 8, 8, 128)    0           bn3conv_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3conv_branch1 (BatchNormaliza (None, 8, 8, 128)    512         res3conv_branch1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 8, 8, 128)    0           leaky_re_lu_9[0][0]
#                                                                  bn3conv_branch1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 8, 8, 128)    0           add_3[0][0]
# __________________________________________________________________________________________________
# res3identity_branch2a (Conv2D)  (None, 8, 8, 128)    147584      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# bn3identity_branch2a (BatchNorm (None, 8, 8, 128)    512         res3identity_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 8, 8, 128)    0           bn3identity_branch2a[0][0]
# __________________________________________________________________________________________________
# res3identity_branch2b (Conv2D)  (None, 8, 8, 128)    147584      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# bn3identity_branch2b (BatchNorm (None, 8, 8, 128)    512         res3identity_branch2b[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 8, 8, 128)    0           bn3identity_branch2b[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 128)    0           leaky_re_lu_12[0][0]
#                                                                  leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 8, 8, 128)    0           add_4[0][0]
# __________________________________________________________________________________________________
# res4conv_branch2a (Conv2D)      (None, 4, 4, 192)    221376      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# bn4conv_branch2a (BatchNormaliz (None, 4, 4, 192)    768         res4conv_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 4, 4, 192)    0           bn4conv_branch2a[0][0]
# __________________________________________________________________________________________________
# res4conv_branch2b (Conv2D)      (None, 4, 4, 192)    331968      leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# bn4conv_branch2b (BatchNormaliz (None, 4, 4, 192)    768         res4conv_branch2b[0][0]
# __________________________________________________________________________________________________
# res4conv_branch1 (Conv2D)       (None, 4, 4, 192)    221376      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 4, 4, 192)    0           bn4conv_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4conv_branch1 (BatchNormaliza (None, 4, 4, 192)    768         res4conv_branch1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, 4, 192)    0           leaky_re_lu_15[0][0]
#                                                                  bn4conv_branch1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 4, 4, 192)    0           add_5[0][0]
# __________________________________________________________________________________________________
# res4identity_branch2a (Conv2D)  (None, 4, 4, 192)    331968      leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# bn4identity_branch2a (BatchNorm (None, 4, 4, 192)    768         res4identity_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 4, 4, 192)    0           bn4identity_branch2a[0][0]
# __________________________________________________________________________________________________
# res4identity_branch2b (Conv2D)  (None, 4, 4, 192)    331968      leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# bn4identity_branch2b (BatchNorm (None, 4, 4, 192)    768         res4identity_branch2b[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 4, 4, 192)    0           bn4identity_branch2b[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 192)    0           leaky_re_lu_18[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 4, 4, 192)    0           add_6[0][0]
# __________________________________________________________________________________________________
# res5conv_branch2a (Conv2D)      (None, 2, 2, 256)    442624      leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# bn5conv_branch2a (BatchNormaliz (None, 2, 2, 256)    1024        res5conv_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 2, 2, 256)    0           bn5conv_branch2a[0][0]
# __________________________________________________________________________________________________
# res5conv_branch2b (Conv2D)      (None, 2, 2, 256)    590080      leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# bn5conv_branch2b (BatchNormaliz (None, 2, 2, 256)    1024        res5conv_branch2b[0][0]
# __________________________________________________________________________________________________
# res5conv_branch1 (Conv2D)       (None, 2, 2, 256)    442624      leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 2, 2, 256)    0           bn5conv_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5conv_branch1 (BatchNormaliza (None, 2, 2, 256)    1024        res5conv_branch1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2, 2, 256)    0           leaky_re_lu_21[0][0]
#                                                                  bn5conv_branch1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 2, 2, 256)    0           add_7[0][0]
# __________________________________________________________________________________________________
# res5identity_branch2a (Conv2D)  (None, 2, 2, 256)    590080      leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# bn5identity_branch2a (BatchNorm (None, 2, 2, 256)    1024        res5identity_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 2, 2, 256)    0           bn5identity_branch2a[0][0]
# __________________________________________________________________________________________________
# res5identity_branch2b (Conv2D)  (None, 2, 2, 256)    590080      leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# bn5identity_branch2b (BatchNorm (None, 2, 2, 256)    1024        res5identity_branch2b[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 2, 2, 256)    0           bn5identity_branch2b[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 2, 2, 256)    0           leaky_re_lu_24[0][0]
#                                                                  leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 2, 2, 256)    0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 256)    0           leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 256)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         263168      flatten_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 1024)         4096        leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# encoder_mean (Dense)            (None, 1024)         1049600     batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# encoder_sigma (Dense)           (None, 1024)         1049600     batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1024)         0           encoder_mean[0][0]
#                                                                  encoder_sigma[0][0]
# ==================================================================================================
# Total params: 7,258,240
# Trainable params: 7,249,664
# Non-trainable params: 8,576
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 512)          0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 512)          0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1024)         0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8192)         8396800     concatenate_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 4, 4, 512)    0           dense_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 4, 4, 512)    0           reshape_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 512)    0           leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# res2conv_dec_branch2a (Conv2D)  (None, 8, 8, 256)    1179904     up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2conv_dec_branch2a (BatchNorm (None, 8, 8, 256)    1024        res2conv_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 8, 8, 256)    0           bn2conv_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# res2conv_dec_branch2b (Conv2D)  (None, 8, 8, 256)    590080      leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 8, 8, 512)    0           leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# bn2conv_dec_branch2b (BatchNorm (None, 8, 8, 256)    1024        res2conv_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# res2conv_dec_branch1 (Conv2D)   (None, 8, 8, 256)    1179904     up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 8, 8, 256)    0           bn2conv_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2conv_dec_branch1 (BatchNorma (None, 8, 8, 256)    1024        res2conv_dec_branch1[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 256)    0           leaky_re_lu_29[0][0]
#                                                                  bn2conv_dec_branch1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 8, 8, 256)    0           add_9[0][0]
# __________________________________________________________________________________________________
# res2identity_dec_branch2a (Conv (None, 8, 8, 256)    590080      leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# bn2identity_dec_branch2a (Batch (None, 8, 8, 256)    1024        res2identity_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 8, 8, 256)    0           bn2identity_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# res2identity_dec_branch2b (Conv (None, 8, 8, 256)    590080      leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# bn2identity_dec_branch2b (Batch (None, 8, 8, 256)    1024        res2identity_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 8, 8, 256)    0           bn2identity_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 256)    0           leaky_re_lu_32[0][0]
#                                                                  leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 8, 8, 256)    0           add_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 16, 16, 256)  0           leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# res3conv_dec_branch2a (Conv2D)  (None, 16, 16, 128)  295040      up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# bn3conv_dec_branch2a (BatchNorm (None, 16, 16, 128)  512         res3conv_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 16, 16, 128)  0           bn3conv_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# res3conv_dec_branch2b (Conv2D)  (None, 16, 16, 128)  147584      leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 16, 16, 256)  0           leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# bn3conv_dec_branch2b (BatchNorm (None, 16, 16, 128)  512         res3conv_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# res3conv_dec_branch1 (Conv2D)   (None, 16, 16, 128)  295040      up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 16, 16, 128)  0           bn3conv_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3conv_dec_branch1 (BatchNorma (None, 16, 16, 128)  512         res3conv_dec_branch1[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 128)  0           leaky_re_lu_35[0][0]
#                                                                  bn3conv_dec_branch1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 16, 16, 128)  0           add_11[0][0]
# __________________________________________________________________________________________________
# res3identity_dec_branch2a (Conv (None, 16, 16, 128)  147584      leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# bn3identity_dec_branch2a (Batch (None, 16, 16, 128)  512         res3identity_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 16, 16, 128)  0           bn3identity_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# res3identity_dec_branch2b (Conv (None, 16, 16, 128)  147584      leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# bn3identity_dec_branch2b (Batch (None, 16, 16, 128)  512         res3identity_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 16, 16, 128)  0           bn3identity_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 128)  0           leaky_re_lu_38[0][0]
#                                                                  leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 16, 16, 128)  0           add_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 32, 32, 128)  0           leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# res4conv_dec_branch2a (Conv2D)  (None, 32, 32, 64)   73792       up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# bn4conv_dec_branch2a (BatchNorm (None, 32, 32, 64)   256         res4conv_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 32, 32, 64)   0           bn4conv_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# res4conv_dec_branch2b (Conv2D)  (None, 32, 32, 64)   36928       leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 32, 32, 128)  0           leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# bn4conv_dec_branch2b (BatchNorm (None, 32, 32, 64)   256         res4conv_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# res4conv_dec_branch1 (Conv2D)   (None, 32, 32, 64)   73792       up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 32, 32, 64)   0           bn4conv_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4conv_dec_branch1 (BatchNorma (None, 32, 32, 64)   256         res4conv_dec_branch1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 32, 32, 64)   0           leaky_re_lu_41[0][0]
#                                                                  bn4conv_dec_branch1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 32, 32, 64)   0           add_13[0][0]
# __________________________________________________________________________________________________
# res4identity_dec_branch2a (Conv (None, 32, 32, 64)   36928       leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# bn4identity_dec_branch2a (Batch (None, 32, 32, 64)   256         res4identity_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 32, 32, 64)   0           bn4identity_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# res4identity_dec_branch2b (Conv (None, 32, 32, 64)   36928       leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# bn4identity_dec_branch2b (Batch (None, 32, 32, 64)   256         res4identity_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 32, 32, 64)   0           bn4identity_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 32, 64)   0           leaky_re_lu_44[0][0]
#                                                                  leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 32, 32, 64)   0           add_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 64, 64, 64)   0           leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# res5conv_dec_branch2a (Conv2D)  (None, 64, 64, 32)   18464       up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# bn5conv_dec_branch2a (BatchNorm (None, 64, 64, 32)   128         res5conv_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 64, 64, 32)   0           bn5conv_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# res5conv_dec_branch2b (Conv2D)  (None, 64, 64, 32)   9248        leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 64, 64, 64)   0           leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# bn5conv_dec_branch2b (BatchNorm (None, 64, 64, 32)   128         res5conv_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# res5conv_dec_branch1 (Conv2D)   (None, 64, 64, 32)   18464       up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 64, 64, 32)   0           bn5conv_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5conv_dec_branch1 (BatchNorma (None, 64, 64, 32)   128         res5conv_dec_branch1[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 64, 64, 32)   0           leaky_re_lu_47[0][0]
#                                                                  bn5conv_dec_branch1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 64, 64, 32)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res5identity_dec_branch2a (Conv (None, 64, 64, 32)   9248        leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# bn5identity_dec_branch2a (Batch (None, 64, 64, 32)   128         res5identity_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 64, 64, 32)   0           bn5identity_dec_branch2a[0][0]
# __________________________________________________________________________________________________
# res5identity_dec_branch2b (Conv (None, 64, 64, 32)   9248        leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# bn5identity_dec_branch2b (Batch (None, 64, 64, 32)   128         res5identity_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 64, 64, 32)   0           bn5identity_dec_branch2b[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 64, 64, 32)   0           leaky_re_lu_50[0][0]
#                                                                  leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 64, 64, 32)   0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 3)    4707        leaky_re_lu_51[0][0]
# ==================================================================================================
# Total params: 13,897,027
# Trainable params: 13,892,227
# Non-trainable params: 4,800
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 1024)         0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           input_2[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 512)          0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 512)          0           input_2[0][0]
# ==================================================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# Encoder (Model)                 [(None, 1024), (None 7258240     input_1[0][0]
# __________________________________________________________________________________________________
# DisentangleNet (Model)          [(None, 512), (None, 0           Encoder[1][2]
# __________________________________________________________________________________________________
# Decoder (Model)                 (None, 64, 64, 3)    13897027    DisentangleNet[1][0]
#                                                                  DisentangleNet[1][1]
# ==================================================================================================
# Total params: 21,155,267
# Trainable params: 21,141,891
# Non-trainable params: 13,376
# __________________________________________________________________________________________________

# %% [markdown]
# # Train the network

# %%
from cleanir.data_loader import VGG2DataGenerator
res_path = '/workspace/data/Results/pubtestver'
batch_size = 32

vgg2_gen = VGG2DataGenerator(PROCESSED_DATA_PATH,
                             batch_size=batch_size, pair=False,
                             has_label_files=True)
cleanir.train(res_path, vgg2_gen)
# Out:
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
# epoch 1 loss [90455.44, 69915.34, 20540.096]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 2 loss [85346.7, 71278.3, 14068.407]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 3 loss [82154.82, 71155.945, 10998.873]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 4 loss [79609.945, 70262.305, 9347.641]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 5 loss [77953.125, 70060.11, 7893.0137]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 6 loss [77212.85, 69535.16, 7677.6943]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 7 loss [74423.984, 67489.89, 6934.096]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 8 loss [75130.35, 69486.625, 5643.727]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 9 loss [74064.555, 68155.36, 5909.194]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 10 loss [75437.62, 70111.86, 5325.7554]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 11 loss [73677.47, 67994.36, 5683.1123]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 12 loss [74152.86, 69586.22, 4566.638]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 13 loss [73684.57, 69268.48, 4416.095]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 14 loss [74099.805, 69003.61, 5096.1943]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 15 loss [72237.555, 67773.86, 4463.697]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 16 loss [74305.36, 70074.836, 4230.524]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 17 loss [73038.05, 69431.06, 3606.9863]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 18 loss [73152.72, 68698.08, 4454.6387]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 19 loss [72786.11, 68652.84, 4133.2676]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 20 loss [70348.984, 66683.84, 3665.1445]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 21 loss [73169.3, 69600.39, 3568.9053]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 22 loss [73382.4, 70317.06, 3065.3325]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 23 loss [73278.625, 70058.65, 3219.9788]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 24 loss [72815.87, 69369.3, 3446.5679]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 25 loss [72391.695, 68728.64, 3663.0537]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 26 loss [69726.945, 66400.945, 3326.0015]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 27 loss [73281.96, 69984.914, 3297.0447]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 28 loss [72097.13, 69097.75, 2999.3813]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 29 loss [71920.15, 68768.22, 3151.929]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 30 loss [70425.125, 67511.12, 2914.0083]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 31 loss [71563.47, 68497.77, 3065.6978]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 32 loss [71339.07, 68791.086, 2547.9807]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 33 loss [71866.414, 69062.21, 2804.2053]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 34 loss [73060.92, 69897.625, 3163.2942]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 35 loss [70918.56, 68216.22, 2702.3445]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 36 loss [72670.81, 69992.2, 2678.6064]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 37 loss [68897.49, 66177.5, 2719.9956]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 38 loss [71083.61, 68421.516, 2662.0898]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 39 loss [71478.74, 68977.484, 2501.2595]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 40 loss [73071.9, 70412.625, 2659.2732]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 41 loss [74007.52, 71230.26, 2777.2688]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
# epoch 42 loss [71858.25, 68965.01, 2893.241]
# HBox(children=(IntProgress(value=0, max=4765), HTML(value='')))
